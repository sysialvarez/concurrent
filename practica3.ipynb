# %% [markdown]
# ### MI ORDENADOR ES UNA SHIIIT?

# %% [markdown]
# # Before

# %%
from IPython import display as dp

# %%
dp.Image("before.png")

# %% [markdown]
# # After

# %%
def fib(n):
    if n in {0,1}:
        return 1
    else:
        return(fib(n-1)+fib(n-2))

# %%
fib(50)

# %%
dp.Image("despues.png")

# %%
import threading as th

# %%
import multiprocessing as mp

# %%
mp.Pool
# Out:
# <bound method BaseContext.Pool of <multiprocessing.context.DefaultContext object at 0x107cbae00>>
